# %% [markdown]
# Assignment 23

# %% [markdown]
# Q1. Load the "titanic" dataset using the load_dataset function of seaborn. Use plotly express to plot a scatter plot for age
#     and fare columns in the titanic dataset.

# %%
#Ans:
import seaborn as sns
titanic=sns.load_dataset("titanic")
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
import plotly.express as px
fig=px.scatter(titanic,x='age',y='fare')
fig.show()
# Out:
# <div>                            <div id="1c415e62-ee93-40ca-a446-038079011ab4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1c415e62-ee93-40ca-a446-038079011ab4")) {                    Plotly.newPlot(                        "1c415e62-ee93-40ca-a446-038079011ab4",                        [{"hovertemplate":"age=%{x}<br>fare=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[22.0,38.0,26.0,35.0,35.0,null,54.0,2.0,27.0,14.0,4.0,58.0,20.0,39.0,14.0,55.0,2.0,null,31.0,null,35.0,34.0,15.0,28.0,8.0,38.0,null,19.0,null,null,40.0,null,null,66.0,28.0,42.0,null,21.0,18.0,14.0,40.0,27.0,null,3.0,19.0,null,null,null,null,18.0,7.0,21.0,49.0,29.0,65.0,null,21.0
# ...

# %% [markdown]
# Q2. Using the tips dataset in the plotly library, plot a box plot using Plotly express.

# %%
#Ans:
import seaborn as sns
tips=sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
import plotly.express as px
df=px.data.tips()
fig=px.box(df,x='total_bill')
fig.show()
# Out:
# <div>                            <div id="a9dc19d1-a472-4f28-a1f2-39970eb7bd6d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a9dc19d1-a472-4f28-a1f2-39970eb7bd6d")) {                    Plotly.newPlot(                        "a9dc19d1-a472-4f28-a1f2-39970eb7bd6d",                        [{"alignmentgroup":"True","hovertemplate":"total_bill=%{x}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"h","showlegend":false,"x":[16.99,10.34,21.01,23.68,24.59,25.29,8.77,26.88,15.04,14.78,10.27,35.26,15.42,18.43,14.83,21.58,10.33,16.29,16.97,20.65,17.92,20.29,15.77,39.42,19.82,17.81,13.37,12.69,21.7,19.65,9.55,18.35,15.06,20.69,17.78,24.06,16.31,16.93,18.69,31.27,16.04,17.46,13.94,9.68,30
# ...

# %% [markdown]
# Q3. Using the tips dataset in the plotly library, plot a histogram for x="sex" and y="total_bill" column in the tips dataset.
#     Also, use the "smoker" column with the pattern_shape parameter and the "day" column with the color parameter.

# %%
#Ans:
import plotly.express as px
df=px.data.tips()
fig=px.histogram(df,x='sex',y='total_bill')
fig.show()
# Out:
# <div>                            <div id="be780e96-af61-4e06-80be-c2bededd46ef" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("be780e96-af61-4e06-80be-c2bededd46ef")) {                    Plotly.newPlot(                        "be780e96-af61-4e06-80be-c2bededd46ef",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"sex=%{x}<br>sum of total_bill=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":["Female","Male","Male","Male","Female","Male","Male","Male","Male","Male","Male","Female","Male","Male","Female","Male","Female","Male","Female","Male","Male","Female","Female","Male","Male","Male","Male"
# ...

# %%
import plotly.express as px
df=px.data.tips()
fig=px.histogram(df,x='sex',y='total_bill',color='day',pattern_shape='smoker')
fig.show()
# Out:
# <div>                            <div id="12e6aa9e-c30e-4831-a736-7f14f5d18686" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("12e6aa9e-c30e-4831-a736-7f14f5d18686")) {                    Plotly.newPlot(                        "12e6aa9e-c30e-4831-a736-7f14f5d18686",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"day=Sun<br>smoker=No<br>sex=%{x}<br>sum of total_bill=%{y}<extra></extra>","legendgroup":"Sun, No","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Sun, No","offsetgroup":"Sun, No","orientation":"v","showlegend":true,"x":["Female","Male","Male","Male","Female","Male","Male","Male","Male","Male","Male","Female","Male","Male","Female","Male","Female","Male","Female","Male","Male","
# ...

# %% [markdown]
# Q4. Using the iris dataset in the plotly library, plot a scatter matrix plot, using the "species" column for the
#     color parameter.

# %%
#Ans:
import seaborn as sns
iris=sns.load_dataset("iris")
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
import plotly.express as px
df=px.data.iris()
fig=px.scatter_matrix(df,color='species')
fig.show()
# Out:
# C:\Users\Arup\anaconda3\lib\site-packages\plotly\express\_core.py:279: FutureWarning:
#
# iteritems is deprecated and will be removed in a future version. Use .items instead.
# ...

# %% [markdown]
# Q5. What is Displot? Using plotly express, plot a displot.

# %% [markdown]
# Ans: The displot figure factory displays a combination of statistical representations of numerical data, such as histogram,
#      kernal, density, estimation or normal curve, and rug plot.

# %%
from plotly.figure_factory import create_distplot
import numpy as np
x=np.random.randn(100)
hist_data=[x]
group_labels=['displot basic example']
fig=create_distplot(hist_data,group_labels)
fig.show()
# Out:
# <div>                            <div id="788a59ea-03a6-4f51-ba9b-852c7a810f93" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("788a59ea-03a6-4f51-ba9b-852c7a810f93")) {                    Plotly.newPlot(                        "788a59ea-03a6-4f51-ba9b-852c7a810f93",                        [{"autobinx":false,"histnorm":"probability density","legendgroup":"displot basic example","marker":{"color":"rgb(31, 119, 180)"},"name":"displot basic example","opacity":0.7,"x":[0.1116610148221636,-0.5681158619215051,-0.804806939836935,-0.015741851492131788,-0.9733169607749682,-1.0996460872430414,1.42179150266153,-0.04708328362805348,-0.846645258686627,0.3462004721715191,1.6888858205915627,-0.5610737567223432,0.41951213692763073,1.9925686025309128,0.0783674258702
# ...
